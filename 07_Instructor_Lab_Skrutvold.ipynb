# %% [markdown]
# ## Week 7 Instructor-led Lab: Data Manipulation
#
# Author: Aerionna Skrutvold
# Course: BGEN632 Grad. Intro to Python
#
# This notebook contains code for the inspection and organization of data based on lab assignment requirements outline. The program primarily makes use of pandas DataFrames and the github_teams.csv file contained within the data folder.

# %% [markdown]
# ### Import Modules

# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold

# %% [markdown]
# ### Set Working Directory

# %%
os.chdir("C:/Users/gcassist/Desktop/MSBA/Spring 25/Python/week7labs/data")

# %% [markdown]
# ### Access Data

# %%
gh_teams = pd.read_csv("github_teams.csv") #open the file

# %%
gh_teams.columns #Find out what the column header names are.
# Out:
# Index(['name_h', 'Team_type', 'Team_size_class', 'human_members_count',
#        'bot_members_count', 'human_work', 'work_per_human', 'human_gini',
#        'human_Push', 'human_IssueComments', 'human_PRReviewComment',
#        'human_MergedPR', 'bot_work', 'bot_Push', 'bot_IssueComments',
#        'bot_PRReviewComment', 'bot_MergedPR', 'eval_survival_day_median',
#        'issues_count'],
#       dtype='object')

# %%
gh_teams.info() # Determine the number of columns.Determine the number of rows.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   name_h                    608 non-null    object
#  1   Team_type                 608 non-null    object
#  2   Team_size_class           608 non-null    object
#  3   human_members_count       608 non-null    int64
#  4   bot_members_count         608 non-null    int64
#  5   human_work                608 non-null    int64
#  6   work_per_human            608 non-null    float64
#  7   human_gini                608 non-null    float64
#  8   human_Push                608 non-null    int64
#  9   human_IssueComments       608 non-null    int64
#  10  human_PRReviewComment     608 non-null    int64
#  11  human_MergedPR            608 non-null    int64
#  12  bot_work                  608 non-null    int64
#  13  bot_Push                  608 non-null    int64
# ...

# %%
gh_teams['name_h'] = gh_teams['name_h'].astype('category') #Determine which columns are categorical and convert them from *object* to *category*.
gh_teams['Team_type'] = gh_teams['Team_type'].astype('category')
gh_teams['Team_size_class'] = gh_teams['Team_size_class'].astype('category')

# %%
gh_teams.info() # Displaying changed column type.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   name_h                    608 non-null    category
#  1   Team_type                 608 non-null    category
#  2   Team_size_class           608 non-null    category
#  3   human_members_count       608 non-null    int64
#  4   bot_members_count         608 non-null    int64
#  5   human_work                608 non-null    int64
#  6   work_per_human            608 non-null    float64
#  7   human_gini                608 non-null    float64
#  8   human_Push                608 non-null    int64
#  9   human_IssueComments       608 non-null    int64
#  10  human_PRReviewComment     608 non-null    int64
#  11  human_MergedPR            608 non-null    int64
#  12  bot_work                  608 non-null    int64
# ...

# %%
pd.unique(gh_teams.Team_type) # How many unique values does `Team_type` have?
# Out:
# ['human-bot', 'human']
# Categories (2, object): ['human', 'human-bot']

# %%
pd.unique(gh_teams.Team_size_class) # How many unique values does `Team_size_class` have?
# Out:
# ['Small', 'Large', 'Medium']
# Categories (3, object): ['Large', 'Medium', 'Small']

# %%
gh_teams.iloc[62,5] # What is the value of the 63rd row and 6th column?
# Out:
# 35

# %%
gh_teams.iloc[299] # What are the values for the 300th row?
# Out:
# name_h                      IyfocAGfAHLncCVJUujqTA/A_QZ6HlUb5sRQHhPa7SGzQ
# Team_type                                                       human-bot
# Team_size_class                                                    Medium
# human_members_count                                                     4
# bot_members_count                                                       1
# human_work                                                           1049
# work_per_human                                                     262.25
# human_gini                                                       0.448761
# human_Push                                                            739
# human_IssueComments                                                   213
# human_PRReviewComment                                                  91
# human_MergedPR                                                          6
# bot_work                                                               52
# ...

# %%
gh_teams.iloc[595,:3 ] # Using three different methods, select row with index value 595 with 1st, 2nd, 3rd columns.
# Out:
# name_h             zAh1NECRCquqUJ_-1d6hAw/DET3jTK8hokYfY_neJ1IVQ
# Team_type                                              human-bot
# Team_size_class                                            Small
# Name: 595, dtype: object

# %%
gh_teams.iloc[595,1:3]
# Out:
# Team_type          human-bot
# Team_size_class        Small
# Name: 595, dtype: object

# %%
gh_teams.iloc[[595],[1,2,3]]
# Out:
#      Team_type Team_size_class  human_members_count
# 595  human-bot           Small                    2

# %%
gh_teams.loc[[46],['Team_size_class','work_per_human']] # Using two different methods, select the row with index value 46 with the 3rd and 7th columns.
# Out:
#    Team_size_class  work_per_human
# 46          Medium       31.833333

# %%
gh_teams.iloc[[46],[3,7]]
# Out:
#     human_members_count  human_gini
# 46                    6    0.506981

# %%
just_bot = pd.DataFrame(gh_teams.bot_work) # Create a new DataFrame for the column `bot_work` using two different methods.

# %%
just_bot2 = gh_teams['bot_work']

# %% [markdown]
# ### Sorting and Ordering data

# %%
gh_teams[(gh_teams.Team_type == 'human-bot') & (gh_teams.bot_members_count >= 2)] # Select `human-bot` teams that have a `bot_members_count` value greater than and equal to 2.
# Out:
#                                             name_h  Team_type Team_size_class  \
# 3    _l5u7I5p4thtW5SjR_9_4w/aZNCdVXta7fh7eCMzZP1CA  human-bot           Large
# 4    _l5u7I5p4thtW5SjR_9_4w/m_FpD7PKQHqVXHn2bh7u2g  human-bot           Large
# 42   2-scMrZv13F95YPZmfieww/4Zc56iUYjIZrZU06omFrJw  human-bot           Large
# 84   4YoH8row044yJjPIqWJw9Q/NSXj3i61X71lV0StTN71Ww  human-bot           Small
# 89   5Is-_ie16OEGmW1arZm8qg/8UeSk2P76pTG7pPLtxsHTQ  human-bot           Large
# 110  7sA-8-nyqr0Ri2CT4-FSZw/GJPQoUhHfvUsxKcdkHWLEw  human-bot           Small
# 146  bi5TY2Z4OSQq3PMs6JnKYA/5wtZcUUo1XmLHIra8NDtFQ  human-bot          Medium
# 147  bi5TY2Z4OSQq3PMs6JnKYA/9b9IqkDK14ketwn88f3hKA  human-bot           Small
# 149  bi5TY2Z4OSQq3PMs6JnKYA/kIiAIJpk6lOa6Nxf234KkQ  human-bot           Small
# 224  FAhkB4rsocfDW0vrM8U8NA/3KHgTzOwWtAxTXlp_mbqoA  human-bot           Large
# 229  FAhkB4rsocfDW0vrM8U8NA/Tl_ZLGwQZrAi-GHyEKl_jA  human-bot           Large
# ...

# %%
gh_teams[(gh_teams.Team_type == 'human') & (gh_teams.Team_size_class == 'Large') & (gh_teams.human_gini >= 0.75)] # Find the `human` teams that are `Large` and have a `human_gini` value greater than and equal to 0.75.
# Out:
#                                             name_h Team_type Team_size_class  \
# 138  ASYGR96YA91p3z7MNKjZCA/IB2pZ8ygcvNnlxUdysjSFA     human           Large
# 285  IiUao8vA_zm_uEIVVLI-Sw/91ya8vlSP8qgwCllH_6BSw     human           Large
# 505  uLHPO58cQefwrJUbyhYOKQ/7YWOP8uDEeKDHQMWKqOoYA     human           Large
# 582  y8Jw59EHVSrsluSuhR5okg/V5vb074jNkzg4YCKforX1Q     human           Large
#
#      human_members_count  bot_members_count  human_work  work_per_human  \
# 138                   12                  0        1655      137.916667
# 285                   25                  0        3599      143.960000
# 505                   48                  0        5748      119.750000
# 582                    8                  0         277       34.625000
#
#      human_gini  human_Push  human_IssueComments  human_PRReviewComment  \
# 138    0.799446         793                  684                    178
# 285    0.863507        1249                 2350                      0
# ...

# %%
count1 = gh_teams[(gh_teams.Team_size_class == 'Small') | (gh_teams.Team_size_class == 'Large')] # How many teams are in the `Small` or `Large` category?
len(count1)
# Out:
# 428

# %%
count2 = gh_teams[((gh_teams.Team_size_class == 'Small') | (gh_teams.Team_size_class == 'Large')) &  (gh_teams.human_gini >= 0.20)] # How many teams are in the `Small` or `Large` cateogry with a `human_gini` value less than and equal to 0.20?
len(count2)
# Out:
# 363

# %%
count3 = [(gh_teams.Team_type == 'human-bot') & (gh_teams.Team_size_class == 'Medium')] # How many `human-bot` teams are in the `Medium` category?
len(count3)
# Out:
# 1

# %%
gh_subsample = gh_teams.sample(frac = 0.5, replace = False) # Create a subsample of 50% of your data.

# %%
kf = KFold(n_splits = 8)  # K-Fold cross-validator with 8 folds   Create samples for a 8-fold cross validation test.

for train, test in kf.split(gh_teams):
    print("%s %s" % (train, test))

gh_teams.iloc[train]
gh_teams.iloc[test]
# Out:
# [ 76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92  93
#   94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110 111
#  112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129
#  130 131 132 133 134 135 136 137 138 139 140 141 142 143 144 145 146 147
#  148 149 150 151 152 153 154 155 156 157 158 159 160 161 162 163 164 165
#  166 167 168 169 170 171 172 173 174 175 176 177 178 179 180 181 182 183
#  184 185 186 187 188 189 190 191 192 193 194 195 196 197 198 199 200 201
#  202 203 204 205 206 207 208 209 210 211 212 213 214 215 216 217 218 219
#  220 221 222 223 224 225 226 227 228 229 230 231 232 233 234 235 236 237
#  238 239 240 241 242 243 244 245 246 247 248 249 250 251 252 253 254 255
#  256 257 258 259 260 261 262 263 264 265 266 267 268 269 270 271 272 273
#  274 275 276 277 278 279 280 281 282 283 284 285 286 287 288 289 290 291
#  292 293 294 295 296 297 298 299 300 301 302 303 304 305 306 307 308 309
# ...

# %%
numeric = gh_teams.select_dtypes(include = ['number']) # Select columns that are numeric and save it as a new DataFrame.

# %%
gh_teams.drop(['bot_PRReviewComment','bot_MergedPR'], axis = 1) # Remove the columns `bot_PRReviewComment` and `bot_MergedPR` from the DataFrame.
# Out:
#                                             name_h  Team_type Team_size_class  \
# 0    _1bqaxzCk0sfQaunsjeViQ/RCEZ3CASdLXbstu9y2JQ7Q  human-bot           Small
# 1    _9o07rGiC7DFyi-zm91Q0g/VOgMsrjYEwFAq0BY8kHqGQ      human           Small
# 2    _DzK53uaZXnAX3WcC0W28g/Epc4QWw5PNBQIIdvopEHDA      human           Large
# 3    _l5u7I5p4thtW5SjR_9_4w/aZNCdVXta7fh7eCMzZP1CA  human-bot           Large
# 4    _l5u7I5p4thtW5SjR_9_4w/m_FpD7PKQHqVXHn2bh7u2g  human-bot           Large
# ..                                             ...        ...             ...
# 603  zTj5tlMWgotzJmQl7BP8wQ/iQ914_smScbUO8BI9JlE6A  human-bot           Small
# 604  zUBexdmYylGGpxiebXm6gg/sJXD2kulWzU35ijdY3SnBQ      human           Small
# 605  zVSBi-iRKCzLiqFwVt6hbg/8SfUBIOeWUjDoQxeUCX7wQ      human          Medium
# 606  zVSBi-iRKCzLiqFwVt6hbg/fm_lDWwc8Uu-aZ24BjUNZg      human          Medium
# 607  ZX09uvu0z_JVPVI-XrPniQ/pxiuGX_R6QI2Euvx2GFIFw  human-bot           Small
#
# ...

# %%
class_size_human_members = gh_teams[['Team_size_class', 'human_members_count']] # Save the columns `Team_size_class` and `human_members_count` as a new DataFrame.

# %%
class_size_human_members.rename(columns = {'Team_size_class':'Class_Size'}, inplace=True) # Rename these two columns in the new DataFrame.
class_size_human_members.rename(columns = {'human_members_count':'Human_Membership'}, inplace=True)
# Out:
# C:\Users\gcassist\AppData\Local\Temp\ipykernel_31448\789983461.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_size_human_members.rename(columns = {'Team_size_class':'Class_Size'}, inplace=True) # Rename these two columns in the new DataFrame.
# C:\Users\gcassist\AppData\Local\Temp\ipykernel_31448\789983461.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_size_human_members.rename(columns = {'human_members_count':'Human_Membership'}, inplace=True)
